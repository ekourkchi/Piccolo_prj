# %% [markdown]
# ## Import Pakcages
#
# **Note:** In this notebook, you need to use the `python_client` in the `piccolo` folder you have donwloaded from Github, where you are running the *piccolo server* locally.
#
# - Import packaged in the order presented in this notebook.
# - Replace `<path_to_piccolo_folder>` with a valid path to the local piccolo folder.

# %%
import sys, os, time
sys.path.insert(0, "/home/asmita/tinyML/piccolo/src/python_client")

# %%
import warnings
warnings.filterwarnings('ignore')
import credentials as crd
from sensiml import *

# %% [markdown]
# ## Conenct to Piccolo
#
# - Use the local URL to connect to the server you are running.
# - Do not remove '/' at the URL address.
# - The local connection uses an insecure protocol, therefore set `insecure=True`.

# %%
client = SensiML(server="http://localhost:8000/", 
                       username=crd.piccolo_user,
                       password=crd.piccolo_pwd,
                       insecure=True)
# Out:
# You have chosen to disable certificate verification. Your connection is not secure!

# %% [markdown]
# ## List Projects
#
# All project stored in the local Piccolo database.

# %%
client.list_projects()
# Out:
#                   Name           Last Modified                 Created  \
# 0     WB_Gesture_local 2025-03-10 16:55:58.000 2025-03-10 16:55:58.000
# 1  WB_Gesture_uploaded 2025-03-10 16:56:41.400 2025-03-10 16:56:41.400
#
#                                    UUID
# 0  921a71c2-6845-426a-96f4-1ef40e88df09
# 1  0b963a86-cdcf-4f5b-9753-aeab8c9ce966

# %% [markdown]
# ## Upload a Project

# %% [markdown]
# **Signature:** `client.upload_project_dcli(name: str, dcli_path: str, force: bool = False)`
#
# Upload a `.dcli` project to the server
#
# **Args:**
#
# -    `name` (str): name of the project to create
# -    `dcli_path` (str): path to the .dclproj file
# -    `force` (bool): attempt to upload to an existing project

# %%
client.upload_project_dcli("WB_Gesture_uploaded_int16", "/home/asmita/tinyML/Piccolo_prj/Gesture/WB_gesture_data_int16/WB_Gesture.dcli", force=True)
# Out:
# Project WB_Gesture_uploaded_int16 does not exist, creating a new project.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 client.upload_project_dcli("WB_Gesture_uploaded_int16", "WB_gesture_data_int16/WB_Gesture.dcli", force=True)
#
# File ~/tinyML/piccolo/src/python_client/sensiml/client.py:1031, in Client.upload_project_dcli(self, name, dcli_path, force)
#    1026     print(
#    1027         "Project with this name already exists. Set force=True to upload dcli data to this project."
#    1028     )
#    1029     return
# -> 1031 upload_project_dcli(self, name, dcli_path)
#
# File ~/tinyML/piccolo/src/python_client/sensiml/dclproj/upload.py:391, in upload_project_dcli(client, name, dcli_path)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# FileNotFoundError: [Errno 2] No such file or directory: 'WB_gesture_data_int16/WB_Gesture.dcli'
